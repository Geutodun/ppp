# %%
import pandas as pd

# %%
practice = pd.DataFrame({'날짜':[], '운동':[], '양':[]})
practice
# Out:
# Empty DataFrame
# Columns: [날짜, 운동, 양]
# Index: []

# %%
practice.loc[0]=['21-3-1', '달리기', 1]
practice
# Out:
#        날짜   운동    양
# 0  21-3-1  달리기  1.0

# %%
practice.loc[1]=['21-3-2', '걷기', 1]
practice.loc[2]=['21-3-2', '달리기', 1]
practice.loc[3]=['21-3-2', '계단오르기', 1]
practice
# Out:
#        날짜     운동    양
# 0  21-3-1    달리기  1.0
# 1  21-3-2     걷기  1.0
# 2  21-3-2    달리기  1.0
# 3  21-3-2  계단오르기  1.0

# %%
practice.loc[4]=['21-3-3', '걷기', 1.5]
practice.loc[5]=['21-3-3', '달리기', 1]
practice
# Out:
#        날짜     운동    양
# 0  21-3-1    달리기  1.0
# 1  21-3-2     걷기  1.0
# 2  21-3-2    달리기  1.0
# 3  21-3-2  계단오르기  1.0
# 4  21-3-3     걷기  1.5
# 5  21-3-3    달리기  1.0

# %%
practice.to_csv("./data/practice.csv", encoding='utf-8')

# %%
pd.read_csv("./data/practice.csv")
# Out:
#    Unnamed: 0      날짜     운동    양
# 0           0  21-3-1    달리기  1.0
# 1           1  21-3-2     걷기  1.0
# 2           2  21-3-2    달리기  1.0
# 3           3  21-3-2  계단오르기  1.0
# 4           4  21-3-3     걷기  1.5
# 5           5  21-3-3    달리기  1.0

# %%
pd.read_csv("./data/practice.csv", index_col=0, encoding='utf-8')
# Out:
#        날짜     운동    양
# 0  21-3-1    달리기  1.0
# 1  21-3-2     걷기  1.0
# 2  21-3-2    달리기  1.0
# 3  21-3-2  계단오르기  1.0
# 4  21-3-3     걷기  1.5
# 5  21-3-3    달리기  1.0

# %%
practice.pivot_table(index="운동")  #평균값 출력
# Out:
#           양
# 운동
# 걷기     1.25
# 계단오르기  1.00
# 달리기    1.00

# %%
import numpy as np

# %%
practice.pivot_table(index="운동", aggfunc=np.sum) #다 더한값 출력
# Out:
#          양
# 운동
# 걷기     2.5
# 계단오르기  1.0
# 달리기    3.0

# %%
practice.pivot_table(index="운동", aggfunc=[np.sum, len])
# Out:
#        sum len
#          양  날짜  양
# 운동
# 걷기     2.5   2  2
# 계단오르기  1.0   1  1
# 달리기    3.0   3  3

# %%
practice.pivot('날짜', '운동', '양')
# Out:
# 운동       걷기  계단오르기  달리기
# 날짜
# 21-3-1  NaN    NaN  1.0
# 21-3-2  1.0    1.0  1.0
# 21-3-3  1.5    NaN  1.0

# %%
prac_pivot = practice.pivot('날짜', '운동', '양')  
prac_pivot.fillna(0, inplace=True)  #NaN 값 0으로 바꿈
prac_pivot
# Out:
# 운동       걷기  계단오르기  달리기
# 날짜
# 21-3-1  0.0    0.0  1.0
# 21-3-2  1.0    1.0  1.0
# 21-3-3  1.5    0.0  1.0
